# %% [markdown]
# ### Ishaan Mehta E18CSE069 EB02 LabWeek1

# %%
#PIL
from PIL import Image
#open
img = Image.open("apple.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=277x280 at 0x1B9BD1DA308>

# %%
#width and height (size) along with some other info
print(img.format, img.size, img.mode)
# Out:
# JPEG (277, 280) RGB

# %%
#save
img.save('./out/apple.jpg')

# %%
#check saved image
Image.open('./out/apple.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=277x280 at 0x1B9BE1B6C88>

# %%
#matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

imgmp = mpimg.imread('./apple.jpg')
plt.imshow(imgmp)

# %%
plt.imsave('./out/mp_apple.jpg', imgmp)

# %%
#checking saved file
plt.imshow(mpimg.imread('./out/mp_apple.jpg'))

# %%
from skimage import io

sk_img = io.imread('./apple.jpg')

io.imshow(sk_img)
#rest same as matplotlib

# %%
import numpy as np

file = open('./bar.raw')
WIDTH = 512
HEIGHT = 512
img = np.fromfile(file, dtype = np.uint8, count = WIDTH*HEIGHT)
img.shape = (HEIGHT, WIDTH)

#Checking the created image using matplotlib
plt.imshow(img)

# %%
#saving

img.astype('int8').tofile('./out/img_created.raw')
